# %%
library(stringr)
library(imputeTS)
library(dplyr)

# %%
patient_info_file = '/Users/m221138/RA_sero_multiomics/preprocessed_data/meta/patient_info.v2.tsv'
patient_df <- read.csv(patient_info_file, sep="\t")

# %%
control_df <- filter(patient_df, acpa == 0)
acpa_pos_df <- filter(patient_df, acpa == 1)
acpa_neg_df <- filter(patient_df, acpa == 2)

# %%
data_df <- rbind(control_df, acpa_pos_df)
fit <- glm(acpa ~ smoking , data = data_df)
summary(fit)
# Out:
# Call:
# glm(formula = acpa ~ smoking, data = data_df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -0.6610  -0.6610   0.3390   0.3390   0.9412
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.66102    0.05695  11.606  < 2e-16 ***
# smoking     -0.60219    0.12042  -5.001 3.72e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 0.1913718)
#
#     Null deviance: 18.947  on 75  degrees of freedom
# Residual deviance: 14.162  on 74  degrees of freedom
#   (4 observations deleted due to missingness)
# AIC: 93.983
#
# Number of Fisher Scoring iterations: 2

# %%
res <- fisher.test(acpa_pos_df$smoking, acpa_neg_df$smoking)
res
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  acpa_pos_df$smoking and acpa_neg_df$smoking
# p-value = 0.05
# alternative hypothesis: true odds ratio is not equal to 1
# 95 percent confidence interval:
#  0.4871711       Inf
# sample estimates:
# odds ratio
#        Inf

# %%
fit <- glm(acpa ~ smoking , data = patient_df)
coef(summary(fit))[,4]
summary(fit)
# Out:
#  (Intercept)      smoking
# 4.217602e-40 5.620112e-01
# Call:
# glm(formula = acpa ~ smoking, data = patient_df)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -0.66667  -0.49351  -0.08009   0.50649   0.50649
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.49351    0.05758  25.937   <2e-16 ***
# smoking      0.17316    0.29735   0.582    0.562
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 0.2553003)
#
#     Null deviance: 20.000  on 79  degrees of freedom
# Residual deviance: 19.913  on 78  degrees of freedom
# AIC: 121.78
#
# Number of Fisher Scoring iterations: 2

# %%
res <- aov(smoking ~ acpa, data = patient_df)
summary(res)
# Out:
#              Df Sum Sq Mean Sq F value   Pr(>F)
# acpa          1  2.831  2.8311   24.72 2.36e-06 ***
# Residuals   114 13.057  0.1145
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
patient_df
# Out:
#     parentID    acpa smoking
# 1    1614800626 2    1
# 2    1516903951 2    1
# 3    1418805487 2    0
# 4    1514103761 2    0
# 5   20170004166 2    0
# 6   19165027849 2    0
# 7   19207030911 2    0
# 8    1415602485 2    0
# 9    1608302954 2    0
# 10   1426606170 2    0
# 11   1523605071 2    0
# 12  19340021998 2    0
# 13   1616801206 2    0
# 14   1419105567 2    0
# 15   1424104362 2    0
# 16  21076016580 2    0
# 17   1510601921 2    0
# 18   1414905833 2    0
# 19   1518105410 2    0
# 20  20224006342 2    0
# 21  19120000023 2    0
# 22   1532904637 2    0
# 23   1509605829 2    0
# 24   1620005122 2    0
# 25   1519405505 2    0
# 26   1611005150 2    0
# 27   1521605352 2    0
# 28  20079004723 2    0
# 29   1421004617 2    0
# 30  19094026780 2    0
# ⋮   ⋮           ⋮    ⋮
# 87  1419200774  0    1
# 88  1323905189  0    1
# 89  1403505741  0    1
# 90  1408001727  0    1
# 91  1321104329  0    1
# 92  1233301450  0    1
# 93  1331806367  0    1
# 94  1330500471  0    1
# 95  1418907189  0    1
# 96  1322100420  0    1
# 97  1402101782  0    0
# 98  1431803035  0    0
# 99  1321207870  0    0
# 100 1500903736  0    0
# 101 1315408885  0    0
# 102 1420903293  0    0
# 103 1312903469  0    0
# 104 1421604010  0    0
# 105 1405504326  0    0
# 106 1507502135  0    0
# 107 1314406698  0    0
# 108 1429504222  0    0
# 109 1405109225  0    0
# 110 1324604997  0    0
# 111 1418303767  0    0
# 112 1324700292  0    0
# 113 1512506677  0    0
# 114 1408402873  0    0
# 115 1312701873  0    0
# 116 1403602272  0    0
