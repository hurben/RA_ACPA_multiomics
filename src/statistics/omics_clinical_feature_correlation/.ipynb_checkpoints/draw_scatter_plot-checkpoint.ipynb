# %%
import pandas as pd
import seaborn as sns

# %%
data_file = '../../../analysis/statistics/omics_clinical_feature_correlation/metabolomics_age.rho.tsv'
data_df = pd.read_csv(data_file, sep="\t")

# %%
data_df[1:10]
# Out:
#    Rank(ACPA–)       Rho  RA_phenotype
# 1            1  0.077252             1
# 2            1  0.422761             0
# 3            2  0.603416             2
# 4            2  0.208897             1
# 5            2  0.358481             0
# 6            3  0.600310             2
# 7            3  0.140087             1
# 8            3  0.157519             0
# 9            4  0.589976             2

# %%
sns.scatterplot(data=data_df, x="Rank(ACPA–)", y="Rho", hue="RA_phenotype", palette=["green","red","blue"])
# Out:
# <AxesSubplot:xlabel='Rank(ACPA–)', ylabel='Rho'>
