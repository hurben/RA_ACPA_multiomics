# %%
import pandas as pd

patient_info_file = "/Users/m221138/RA_acpa_multiomics/preprocessed_data/meta/patient_info_for_statistics.tsv"
three_omics_file = "/Users/m221138/RA_acpa_multiomics/preprocessed_data/3_omics/three_omics_multiplex.tsv"

# %%
three_omics_df = pd.read_csv(three_omics_file,sep="\t")

# %%
three_omics_df[5:]
# Out:
#             Unnamed: 0    1611904194    1418805487   21028008359  \
# 5              aa_A1BG    956.406597    837.531250   1015.992361
# 6              aa_AAK1   2326.303472   1877.855903   2573.625694
# 7              aa_AARS   1064.409028   1214.445833   1096.303125
# 8             aa_ABCF1   1354.126389   1078.518750    984.520139
# 9             aa_ABCF3   2085.495833   1412.806597   1257.934722
# ...                ...           ...           ...           ...
# 9944  p_ZNF264_9993-11   1214.200000   1024.100000   1184.900000
# 9945  p_ATP4B_9994-217   1384.800000   1378.300000   1450.800000
# 9946      p_DUT_9995-6  12264.200000   2919.700000  12128.800000
# 9947   p_UBXN4_9997-12  52126.300000  16537.700000  56137.500000
# 9948     p_IRF6_9999-1   4109.700000   2014.900000   5974.400000
#
#         1402101782    1610902229    1514103761   20170004166    1401405787  \
# 5      1035.665278   1046.377083   1106.767014   1035.334375   1124.528472
# ...

# %%
patient_info_file
# Out:
# '/Users/m221138/RA_acpa_multiomics/preprocessed_data/meta/patient_info_for_statistics.tsv'
