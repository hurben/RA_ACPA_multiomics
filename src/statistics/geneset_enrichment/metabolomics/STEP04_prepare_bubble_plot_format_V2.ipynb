# %%
#STEP04_STEP04_prepare_bubble_plot_format_V2.ipynb

#For creating a bubble plot of:
#X-axis: ACPA-neg up, ACPA-neg down, ACPA-pos up, ACPA-pos down
#Y-axis: Pathways
#circle size: number of DAM/ pathway size
#circle color: -log10(p-value)

#make data matrix of
#1st column: Pathway name, 
#2nd column: condition
#3rd column: -log10(P-value)
#4th column: number of DAM / pathway size

# %%
import pandas as pd
import math

# %%
data_dict = {}

pathway_list = []
sig_pathway_list = []

condition_list = ["cVSneg", "cVSpos"]
regulation_list = ["up","down"]

for condition in condition_list:
    for regulation in regulation_list:
        label_pathway_list = []

        label = "%s_%s" % (condition, regulation)
                
        data_file = "../../../../analysis/statistics/gse/metabolomics/metabolomics.%s.%s.hypergeometric.result.tsv" % (condition, regulation)
        data_df = pd.read_csv(data_file, sep = "\t")
        r, _ = data_df.shape
        
        for i in range(r):
            pathway = data_df["pathway"][i]
           
            pval = float(data_df["pvalue"][i])
            
            if pval < 0.05:
                sig_pathway_list.append(pathway)
                
            logpval = -math.log10(pval)
            pathway_list.append(pathway)
            label_pathway_list.append(pathway)
        
            try: data_dict[label, pathway][0] = logpval
            except KeyError: data_dict[label, pathway] = [logpval, 'nan', 'nan']

        data_file = "../../../../analysis/statistics/gse/metabolomics/metabolomics.%s.%s.hypergeometric.ready.tsv" % (condition, regulation)
        data_df = pd.read_csv(data_file, sep = "\t")
        r, _ = data_df.shape
        
        for i in range(r):
            pathway = data_df["pathway"][i]
            
            if pathway in label_pathway_list:          
                denominator = data_df["number_of_metabolites_in_pathway(m)"][i]
                numerator = data_df["significant_metabolites_in_pathway(x)"][i]
                
                data_dict[label, pathway][1] = numerator
                data_dict[label, pathway][2] = denominator

pathway_list = list(set(pathway_list))
sig_pathway_list = list(set(sig_pathway_list))

output_file = "../../../../analysis/statistics/gse/metabolomics/plot/bubble_plot_ready.tsv"
output_txt = open(output_file,'w')

output_txt.write("data_label\tpathway\tsignificance\tnum_sig_met\tnum_met_in_pathway\n")

for condition in condition_list:
    for regulation in regulation_list:
        
        data_label = "%s_%s" % (condition, regulation)
        
        for pathway in sig_pathway_list:
            
            try: logpval = data_dict[data_label, pathway][0]
            except KeyError: logpval = 0
            
            try: 
                numerator = data_dict[data_label, pathway][1]
                denominator = data_dict[data_label, pathway][2]
            except KeyError: 
                numerator = 0
                denominator = 0
            
            print (data_label, pathway, logpval, numerator, denominator)
            
            output_txt.write("%s\t%s\t%s\t%s\t%s\n" % (data_label, pathway, logpval, numerator, denominator))
            
output_txt.close()
# Out:
# cVSneg_up [Amino Acid] Methionine, Cysteine, SAM and Taurine Metabolism 0 0 0
# cVSneg_up [Lipid] Long Chain Monounsaturated Fatty Acid 4.0 4 8
# cVSneg_up [Lipid] Medium Chain Fatty Acid 2.744727494896694 3 8
# cVSneg_up [Amino Acid] Urea cycle; Arginine and Proline Metabolism 0 0 0
# cVSneg_up [Cofactors and Vitamins] Vitamin A Metabolism 0 0 0
# cVSneg_up [Nucleotide] Pyrimidine Metabolism, Uracil containing 0 0 0
# cVSneg_up [Lipid] Carnitine Metabolism 0 0 0
# cVSneg_up [Lipid] Fatty Acid Metabolism (Acyl Choline) 0 0 0
# cVSneg_up [Lipid] Long Chain Saturated Fatty Acid 3.5228787452803374 3 5
# cVSneg_up [Lipid] Ceramides 1.4596705252091262 2 9
# cVSneg_up [Lipid] Corticosteroids 0 0 0
# cVSneg_up [Lipid] Sphingosines 1.0065637695023884 1 3
# cVSneg_up [Xenobiotics] Chemical 0.6339507901997645 2 27
# cVSneg_up [Amino Acid] Tryptophan Metabolism 0 0 0
# cVSneg_up [Peptide] Modified Peptides 0 0 0
# cVSneg_up [Cofactors and Vitamins] Hemoglobin and Porphyrin Metabolism 0 0 0
# cVSneg_up [Amino Acid] Histidine Metabolism 0 0 0
# cVSneg_down [Amino Acid] Methionine, Cysteine, SAM and Taurine Metabolism 0.1859522790044006 2 24
# cVSneg_down [Lipid] Long Chain Monounsaturated Fatty Acid 0 0 0
# cVSneg_down [Lipid] Medium Chain Fatty Acid 0 0 0
# cVSneg_down [Amino Acid] Urea cycle; Arginine and Proline Metabolism 0.4119525030139173 2 22
# cVSneg_down [Cofactors and Vitamins] Vitamin A Metabolism 0 0 0
# cVSneg_down [Nucleotide] Pyrimidine Metabolism, Uracil containing 0.8579235389267151 2 11
# cVSneg_down [Lipid] Carnitine Metabolism 2.4436974992327127 2 2
# cVSneg_down [Lipid] Fatty Acid Metabolism (Acyl Choline) 1.869666231504994 3 9
# cVSneg_down [Lipid] Long Chain Saturated Fatty Acid 0 0 0
# cVSneg_down [Lipid] Ceramides 0 0 0
# cVSneg_down [Lipid] Corticosteroids 2.721246399047171 3 5
# cVSneg_down [Lipid] Sphingosines 0 0 0
# cVSneg_down [Xenobiotics] Chemical 0.17043894370060728 2 27
# cVSneg_down [Amino Acid] Tryptophan Metabolism -0.0 1 25
# cVSneg_down [Peptide] Modified Peptides 0 0 0
# cVSneg_down [Cofactors and Vitamins] Hemoglobin and Porphyrin Metabolism 1.4975728800155672 2 5
# cVSneg_down [Amino Acid] Histidine Metabolism 0.5627252025898763 2 17
# cVSpos_up [Amino Acid] Methionine, Cysteine, SAM and Taurine Metabolism 0 0 0
# cVSpos_up [Lipid] Long Chain Monounsaturated Fatty Acid 0 0 0
# cVSpos_up [Lipid] Medium Chain Fatty Acid 1.1354889189416082 1 8
# cVSpos_up [Amino Acid] Urea cycle; Arginine and Proline Metabolism 0 0 0
# cVSpos_up [Cofactors and Vitamins] Vitamin A Metabolism 0 0 0
# cVSpos_up [Nucleotide] Pyrimidine Metabolism, Uracil containing 0 0 0
# cVSpos_up [Lipid] Carnitine Metabolism 0 0 0
# cVSpos_up [Lipid] Fatty Acid Metabolism (Acyl Choline) 0 0 0
# cVSpos_up [Lipid] Long Chain Saturated Fatty Acid 0 0 0
# cVSpos_up [Lipid] Ceramides 1.0861861476162833 1 9
# cVSpos_up [Lipid] Corticosteroids 0 0 0
# cVSpos_up [Lipid] Sphingosines 1.5528419686577808 1 3
# cVSpos_up [Xenobiotics] Chemical 1.6055483191737838 2 27
# cVSpos_up [Amino Acid] Tryptophan Metabolism 0 0 0
# cVSpos_up [Peptide] Modified Peptides 0 0 0
# cVSpos_up [Cofactors and Vitamins] Hemoglobin and Porphyrin Metabolism 0 0 0
# cVSpos_up [Amino Acid] Histidine Metabolism 0 0 0
# cVSpos_down [Amino Acid] Methionine, Cysteine, SAM and Taurine Metabolism 2.769551078621726 5 24
# cVSpos_down [Lipid] Long Chain Monounsaturated Fatty Acid 0 0 0
# cVSpos_down [Lipid] Medium Chain Fatty Acid 0 0 0
# cVSpos_down [Amino Acid] Urea cycle; Arginine and Proline Metabolism 1.3053948010664314 3 22
# cVSpos_down [Cofactors and Vitamins] Vitamin A Metabolism 1.7033348097384688 2 6
# cVSpos_down [Nucleotide] Pyrimidine Metabolism, Uracil containing 2.1487416512809245 3 11
# cVSpos_down [Lipid] Carnitine Metabolism 1.1203307943679464 1 2
# cVSpos_down [Lipid] Fatty Acid Metabolism (Acyl Choline) 0 0 0
# cVSpos_down [Lipid] Long Chain Saturated Fatty Acid 0 0 0
# cVSpos_down [Lipid] Ceramides 0 0 0
# cVSpos_down [Lipid] Corticosteroids 0 0 0
# cVSpos_down [Lipid] Sphingosines 0 0 0
# cVSpos_down [Xenobiotics] Chemical -0.0 1 27
# cVSpos_down [Amino Acid] Tryptophan Metabolism 1.869666231504994 4 25
# cVSpos_down [Peptide] Modified Peptides 1.413412695328245 1 1
# cVSpos_down [Cofactors and Vitamins] Hemoglobin and Porphyrin Metabolism 0 0 0
# cVSpos_down [Amino Acid] Histidine Metabolism 1.6020599913279623 3 17
