# %%
import pandas as pd
import math

# %%
#For creating a bubble plot of:
#X-axis: ACPA-neg up, ACPA-neg down, ACPA-pos up, ACPA-pos down
#Y-axis: Pathways
#circle size: number of DAM/ pathway size
#circle color: -log10(p-value)

#make data matrix of
#1st column: Pathway name, 
#2nd column: condition
#3rd column: -log10(P-value)
#4th column: number of DAM / pathway size

pvalue_file = "../../../../analysis/statistics/gse/metabolomics_p0.05/metabolomics.cVSneg.down.hypergeometric.result.tsv"
pvalue_df = pd.read_csv(pvalue_file, sep="\t")

# %%
data_dict = {}

pathway_list = []

condition_list = ["cVSneg", "cVSpos"]
regulation_list = ["up","down"]

for condition in condition_list:
    for regulation in regulation_list:
        label_pathway_list = []

        label = "%s_%s" % (condition, regulation)
                
        data_file = "../../../../analysis/statistics/gse/metabolomics_p0.05/metabolomics.%s.%s.hypergeometric.result.tsv" % (condition, regulation)
        data_df = pd.read_csv(data_file, sep = "\t")
        r, _ = data_df.shape
        
        for i in range(r):
            pathway = data_df["pathway"][i]
           
            pval = float(data_df["pvalue"][i])
            
            if pval < 0.05:
                logpval = -math.log10(pval)
                pathway_list.append(pathway)
                label_pathway_list.append(pathway)
            
                try: data_dict[label, pathway][0] = logpval
                except KeyError: data_dict[label, pathway] = [logpval, 'nan', 'nan']

        data_file = "../../../../analysis/statistics/gse/metabolomics_p0.05/metabolomics.%s.%s.hypergeometric.ready.tsv" % (condition, regulation)
        data_df = pd.read_csv(data_file, sep = "\t")
        r, _ = data_df.shape
        
        for i in range(r):
            pathway = data_df["pathway"][i]
            
            if pathway in label_pathway_list:          
                denominator = data_df["number_of_metabolites_in_pathway(m)"][i]
                numerator = data_df["significant_metabolites_in_pathway(x)"][i]
                
                data_dict[label, pathway][1] = numerator
                data_dict[label, pathway][2] = denominator

pathway_list = list(set(pathway_list))

# %%
output_file = "../../../../analysis/statistics/gse/metabolomics_p0.05/plot/bubble_plot_ready.tsv"
output_txt = open(output_file,'w')

output_txt.write("data_label\tpathway\tsignificance\tnum_sig_met\tnum_met_in_pathway\n")

for condition in condition_list:
    for regulation in regulation_list:
        
        data_label = "%s_%s" % (condition, regulation)
        
        for pathway in pathway_list:
            
            try: logpval = data_dict[data_label, pathway][0]
            except KeyError: logpval = 0
            
            try: 
                numerator = data_dict[data_label, pathway][1]
                denominator = data_dict[data_label, pathway][2]
            except KeyError: 
                numerator = 0
                denominator = 0
            
            print (data_label, pathway, logpval, numerator, denominator)
            
            output_txt.write("%s\t%s\t%s\t%s\t%s\n" % (data_label, pathway, logpval, numerator, denominator))
            
output_txt.close()
# Out:
# cVSneg_up [Carbohydrate] Glycolysis, Gluconeogenesis, and Pyruvate Metabolism 1.8601209135987635 2 6
# cVSneg_up [Lipid] Carnitine Metabolism 0 0 0
# cVSneg_up [Lipid] Sphingolipid Synthesis 2.537602002101044 2 3
# cVSneg_up [Lipid] Ceramides 1.5058454059815571 2 9
# cVSneg_up [Lipid] Medium Chain Fatty Acid 2.8239087409443187 3 8
# cVSneg_up [Lipid] Endocannabinoid 1.6073030467403342 2 8
# cVSneg_up [Lipid] Short Chain Fatty Acid 0 0 0
# cVSneg_up [Lipid] Sphingosines 2.537602002101044 2 3
# cVSneg_up [Amino Acid] Glutathione Metabolism 1.723538195826756 2 7
# cVSneg_up [Amino Acid] Glycine, Serine and Threonine Metabolism 0 0 0
# cVSneg_up [Lipid] Monoacylglycerol 0 0 0
# cVSneg_up [Lipid] Phosphatidylethanolamine (PE) 0 0 0
# cVSneg_up [Amino Acid] Alanine and Aspartate Metabolism 0 0 0
# cVSneg_up [Nucleotide] Pyrimidine Metabolism, Cytidine containing 0 0 0
# cVSneg_down [Carbohydrate] Glycolysis, Gluconeogenesis, and Pyruvate Metabolism 0 0 0
# cVSneg_down [Lipid] Carnitine Metabolism 2.2596373105057563 2 2
# cVSneg_down [Lipid] Sphingolipid Synthesis 0 0 0
# cVSneg_down [Lipid] Ceramides 0 0 0
# cVSneg_down [Lipid] Medium Chain Fatty Acid 0 0 0
# cVSneg_down [Lipid] Endocannabinoid 0 0 0
# cVSneg_down [Lipid] Short Chain Fatty Acid 0 0 0
# cVSneg_down [Lipid] Sphingosines 0 0 0
# cVSneg_down [Amino Acid] Glutathione Metabolism 0 0 0
# cVSneg_down [Amino Acid] Glycine, Serine and Threonine Metabolism 0 0 0
# cVSneg_down [Lipid] Monoacylglycerol 0 0 0
# cVSneg_down [Lipid] Phosphatidylethanolamine (PE) 0 0 0
# cVSneg_down [Amino Acid] Alanine and Aspartate Metabolism 1.6179829574251317 3 9
# cVSneg_down [Nucleotide] Pyrimidine Metabolism, Cytidine containing 1.3260580013659122 2 5
# cVSpos_up [Carbohydrate] Glycolysis, Gluconeogenesis, and Pyruvate Metabolism 0 0 0
# cVSpos_up [Lipid] Carnitine Metabolism 0 0 0
# cVSpos_up [Lipid] Sphingolipid Synthesis 0 0 0
# cVSpos_up [Lipid] Ceramides 0 0 0
# cVSpos_up [Lipid] Medium Chain Fatty Acid 0 0 0
# cVSpos_up [Lipid] Endocannabinoid 2.0132282657337552 2 8
# cVSpos_up [Lipid] Short Chain Fatty Acid 1.7033348097384688 1 1
# cVSpos_up [Lipid] Sphingosines 0 0 0
# cVSpos_up [Amino Acid] Glutathione Metabolism 0 0 0
# cVSpos_up [Amino Acid] Glycine, Serine and Threonine Metabolism 0 0 0
# cVSpos_up [Lipid] Monoacylglycerol 0 0 0
# cVSpos_up [Lipid] Phosphatidylethanolamine (PE) 0 0 0
# cVSpos_up [Amino Acid] Alanine and Aspartate Metabolism 0 0 0
# cVSpos_up [Nucleotide] Pyrimidine Metabolism, Cytidine containing 0 0 0
# cVSpos_down [Carbohydrate] Glycolysis, Gluconeogenesis, and Pyruvate Metabolism 0 0 0
# cVSpos_down [Lipid] Carnitine Metabolism 0 0 0
# cVSpos_down [Lipid] Sphingolipid Synthesis 0 0 0
# cVSpos_down [Lipid] Ceramides 0 0 0
# cVSpos_down [Lipid] Medium Chain Fatty Acid 0 0 0
# cVSpos_down [Lipid] Endocannabinoid 0 0 0
# cVSpos_down [Lipid] Short Chain Fatty Acid 0 0 0
# cVSpos_down [Lipid] Sphingosines 0 0 0
# cVSpos_down [Amino Acid] Glutathione Metabolism 0 0 0
# cVSpos_down [Amino Acid] Glycine, Serine and Threonine Metabolism 1.3178549236261683 3 11
# cVSpos_down [Lipid] Monoacylglycerol 1.712198270069774 3 8
# cVSpos_down [Lipid] Phosphatidylethanolamine (PE) 1.7212463990471711 4 14
# cVSpos_down [Amino Acid] Alanine and Aspartate Metabolism 0 0 0
# cVSpos_down [Nucleotide] Pyrimidine Metabolism, Cytidine containing 0 0 0
