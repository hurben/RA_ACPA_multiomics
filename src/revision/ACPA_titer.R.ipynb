# %%
library(ggplot2)
library(readr)

# %%
# Load data
data_file <- "/Users/m221138/RA_ACPA_multiomics/preprocessed_data/meta/patient_info_for_statistics.v5.tsv"
df <- read.csv(data_file, sep="\t")

# %%
# Histogram with binwidth = 20 and x-axis ticks at 20,40,60,...
ggplot(df, aes(x = acpa_tit, fill = factor(acpa))) +
  geom_histogram(binwidth = 5, color = "black") +
  labs(x = "ACPA Titer", y = "Count", fill = "ACPA") +
  theme_minimal()
# Out:
# Warning message:
# “Removed 63 rows containing non-finite outside the scale range (`stat_bin()`).”
# plot without title
