# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

data_file = "/Users/m221138/RA_ACPA_multiomics/preprocessed_data/meta/patient_info_for_statistics.v5.tsv"
data_df = pd.read_csv(data_file, sep="\t")

data_df = data_df[data_df["acpa"].isin([1, 2])]
acpa_pos = data_df[data_df["acpa"] == 1]
acpa_neg = data_df[data_df["acpa"] == 2]

# Histogram
# sns.histplot(data=data_df, x="acpa_tit", hue="acpa", binwidth=20)
sns.histplot(
    data=data_df, x="acpa_tit", hue="acpa",
    binwidth=5,
    shrink=0.9
)
# Out:
# <Axes: xlabel='acpa_tit', ylabel='Count'>
