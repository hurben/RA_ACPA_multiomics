# %%
#01_PREPROCESS_RA_ART_metabolomics.ipynb

import pandas as pd
import numpy as np
import math
import statistics

# %%
def main(data_file,output_file):
    count_nan = 0
    data_dict = {}
    metabolite_dict = {}
    
    data_df = pd.read_csv(data_file, sep="\t", index_col=0, thousands=',')
    r, c = data_df.shape
    
    metabolite_list = data_df.index.values
    sample_list = data_df.columns.values
    
    print (len(metabolite_list))
    print (len(sample_list))
    nan_cutoff = int(len(sample_list) * 0.2) #if metabolites have more than 20% of N/A values, it will be removed 
    
    #output
    output_txt = open(output_file,'w')
    for sample in sample_list:
        output_txt.write('\t%s' % sample)
    output_txt.write('\n')
    
    #check which metabolites does not meet criteria (too many N/As)
    for i in range(r):
        metabolite = metabolite_list[i]
        value_list = data_df.iloc[i]
        normalized_value_list = []
        temp_list = []

        if metabolite == "ccp":
            output_txt.write("acpa")
            for value in value_list:
                output_txt.write('\t%s' % value)
            output_txt.write('\n')
        else:
            
            num_nan = value_list.isna().sum()
            metabolite_median = value_list.median()
            
            if num_nan < nan_cutoff:
                output_txt.write(metabolite)
                for value in value_list:
                    #if isinstance(value, np.float) == True or isinstance(value, np.float64) == True:
                    if math.isnan(value) == True:
                        if math.isnan(value) == True:
                            normalized_value_list.append('nan')
                        else:
                            normalized_value = float(value) / float(metabolite_median)
                            normalized_value_list.append(normalized_value)
                            temp_list.append(normalized_value)
    
                    else: #for np.object
                        normalized_value = float(value) / float(metabolite_median)
                        normalized_value_list.append(normalized_value)
                        temp_list.append(normalized_value)
    
                #replace nan to mimimum value
                min_value = min(temp_list)
                for i in range(len(normalized_value_list)):
                    value = normalized_value_list[i]
                    if value == 'nan':
                        normalized_value_list[i] = min_value
                        
                for value in normalized_value_list:
                    output_txt.write('\t%s' % value)
                output_txt.write('\n')
            else:
                print ("%s has too many nan (%s/%s). This will be excluded" % (metabolite, num_nan, nan_cutoff))
                count_nan += 1
            
    print (count_nan)
    output_txt.close()

# %%
#get ST, sample ID link
accrual_report_file = "../../../analysis_revision/external_validation/ra_art_metabolomics/raw_data/accrual_report_hd4.csv"
accrual_report_df = pd.read_csv(accrual_report_file, dtype=str)
accrual_report_df = accrual_report_df[["Sample Id","External_Participant_Id"]]

#get sample ID, ACPA link
ra_biobank_file = "../../../analysis_revision/external_validation/ra_art_metabolomics/raw_data/RA_biobank_2019June17_sheet1.csv"
ra_biobank_df = pd.read_csv(ra_biobank_file)
ra_biobank_df = ra_biobank_df[["External_Participant_Id", "ccp"]]

#get sample ID from plamsa data
plasma_m_file = "../../../analysis_revision/external_validation/ra_art_metabolomics/raw_data/RA_plasma_metabolomics.csv"
plasma_m_df = pd.read_csv(plasma_m_file, header=None, index_col=0)
plasma_m_df = plasma_m_df.T
plasma_m_sample_ID_list = list(plasma_m_df["sample_id"])

# %%
accrual_report_df = accrual_report_df[accrual_report_df['Sample Id'].isin(plasma_m_sample_ID_list)]

merged_df = pd.merge(accrual_report_df, ra_biobank_df, on='External_Participant_Id', how='inner')
merged_df = merged_df.drop_duplicates()

# merged_df.to_csv("../../analysis_addressing_feedback/external_validation/ra_plasma_metabolomics/data/RA_plasma_metabolomics.patient_info.csv", index=False)

final_df = pd.merge(merged_df, plasma_m_df, left_on='Sample Id', right_on='sample_id',  how='left')
final_df = final_df.dropna(subset=['ccp'])
# final_df["ccp"].replace({"positive": 1, "negative": 2}, inplace=True)

final_df["ccp"] = final_df["ccp"].replace({"positive": 1, "negative": 2}).infer_objects()
final_df = final_df.drop(columns=["External_Participant_Id","sample_id","PARENT SAMPLE ID","SAMPLE NAME","RESPONDER STATUS","SAMPLENUMBER","SAMPLE AMOUNT","SUBJECT ID","TIME POINT","etc"])
final_df = final_df.T
final_df.to_csv("../../../analysis_revision/external_validation/ra_art_metabolomics/data/RA_art_metabolomics.patient_info.tsv", sep="\t", header=False)
# Out:
# /var/folders/7g/bxl6lwtx2z1dztdmxklgjd100000gr/T/ipykernel_5255/2810473767.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   final_df["ccp"] = final_df["ccp"].replace({"positive": 1, "negative": 2}).infer_objects()

# %%
data_file = '../../../analysis_revision/external_validation/ra_art_metabolomics/data/RA_art_metabolomics.patient_info.tsv'
output_file = '../../../analysis_revision/external_validation/ra_art_metabolomics/data/RA_art_metabolomics.scaled.patient_info.tsv'

# %%
main(data_file, output_file)
# Out:
# 895
# 131
# (2,4 or 2,5)-dimethylphenol sulfate has too many nan (48/26). This will be excluded
# 1-arachidonoyl-GPA (20:4) has too many nan (41/26). This will be excluded
# 1-hydroxy-2-naphthalenecarboxylate has too many nan (124/26). This will be excluded
# 1-oleoyl-GPS (18:1) has too many nan (58/26). This will be excluded
# 1-palmitoyl-GPA (16:0) has too many nan (63/26). This will be excluded
# 1-stearoyl-GPS (18:0)* has too many nan (39/26). This will be excluded
# 10-hydroxywarfarin has too many nan (123/26). This will be excluded
# 11-ketoetiocholanolone glucuronide has too many nan (67/26). This will be excluded
# 1H-indole-7-acetic acid has too many nan (43/26). This will be excluded
# 2'-deoxyuridine has too many nan (29/26). This will be excluded
# 2-acetamidophenol sulfate has too many nan (72/26). This will be excluded
# 2-hydroxyacetaminophen sulfate* has too many nan (71/26). This will be excluded
# 2-hydroxyibuprofen has too many nan (101/26). This will be excluded
# 2-isopropylmalate has too many nan (31/26). This will be excluded
# 2-methoxyacetaminophen glucuronide* has too many nan (86/26). This will be excluded
# 2-methoxyacetaminophen sulfate* has too many nan (91/26). This will be excluded
# 2-methoxyresorcinol sulfate has too many nan (70/26). This will be excluded
# 2-methylbutyrylglycine (C5) has too many nan (30/26). This will be excluded
# 2-methylcitrate/homocitrate has too many nan (44/26). This will be excluded
# 3-(3-hydroxyphenyl)propionate sulfate has too many nan (35/26). This will be excluded
# 3-(4-hydroxyphenyl)propionate has too many nan (57/26). This will be excluded
# 3-(cystein-S-yl)acetaminophen* has too many nan (85/26). This will be excluded
# 3-(methylthio)acetaminophen sulfate* has too many nan (68/26). This will be excluded
# 3-(N-acetyl-L-cystein-S-yl) acetaminophen has too many nan (84/26). This will be excluded
# 3-acetylphenol sulfate has too many nan (27/26). This will be excluded
# 3-ethylcatechol sulfate (2) has too many nan (64/26). This will be excluded
# 3-hydroxy-2-methylpyridine sulfate has too many nan (29/26). This will be excluded
# 3-hydroxyhippurate sulfate has too many nan (46/26). This will be excluded
# 3-hydroxyindolin-2-one sulfate has too many nan (38/26). This will be excluded
# 3-hydroxyphenylacetoylglutamine has too many nan (29/26). This will be excluded
# 3-hydroxypyridine glucuronide has too many nan (54/26). This will be excluded
# 3-hydroxysebacate has too many nan (49/26). This will be excluded
# 3-methoxycatechol sulfate (2) has too many nan (46/26). This will be excluded
# 3-methyl catechol sulfate (2) has too many nan (47/26). This will be excluded
# 4-acetamidophenol has too many nan (85/26). This will be excluded
# 4-acetamidophenylglucuronide has too many nan (68/26). This will be excluded
# 4-acetaminophen sulfate has too many nan (56/26). This will be excluded
# 4-cholesten-3-one has too many nan (32/26). This will be excluded
# 4-hydroxy duloxetine glucuronide* has too many nan (130/26). This will be excluded
# 4-hydroxyglutamate has too many nan (33/26). This will be excluded
# 4-methoxyphenol sulfate has too many nan (37/26). This will be excluded
# 4-methylhexanoylglutamine has too many nan (41/26). This will be excluded
# 4-vinylguaiacol sulfate has too many nan (29/26). This will be excluded
# 5-hydroxy-6-methoxy duloxetine sulfate* has too many nan (130/26). This will be excluded
# 5-hydroxyindole sulfate has too many nan (64/26). This will be excluded
# 5-hydroxyindoleacetate has too many nan (43/26). This will be excluded
# 5alpha-androstan-3alpha,17beta-diol monosulfate (1) has too many nan (31/26). This will be excluded
# 5alpha-androstan-3alpha,17beta-diol monosulfate (2) has too many nan (91/26). This will be excluded
# 5alpha-androstan-3beta,17alpha-diol disulfate has too many nan (49/26). This will be excluded
# 5alpha-androstan-3beta,17beta-diol monosulfate (2) has too many nan (46/26). This will be excluded
# 6-hydroxywarfarin has too many nan (123/26). This will be excluded
# 7-hydroxywarfarin has too many nan (123/26). This will be excluded
# 7-methylxanthine has too many nan (50/26). This will be excluded
# 8-methoxykynurenate has too many nan (28/26). This will be excluded
# acesulfame has too many nan (48/26). This will be excluded
# ADP has too many nan (41/26). This will be excluded
# alliin has too many nan (28/26). This will be excluded
# allopurinol has too many nan (129/26). This will be excluded
# allopurinol riboside has too many nan (127/26). This will be excluded
# alpha-CEHC sulfate has too many nan (65/26). This will be excluded
# alpha-hydroxycaproate has too many nan (44/26). This will be excluded
# alpha-hydroxymetoprolol has too many nan (87/26). This will be excluded
# andro steroid monosulfate C19H28O6S (1)* has too many nan (39/26). This will be excluded
# androstenediol (3alpha, 17alpha) monosulfate (2) has too many nan (32/26). This will be excluded
# arachidoylcarnitine (C20)* has too many nan (68/26). This will be excluded
# atenolol has too many nan (114/26). This will be excluded
# azithromycin has too many nan (126/26). This will be excluded
# baclofen has too many nan (129/26). This will be excluded
# behenate (22:0)* has too many nan (26/26). This will be excluded
# benzoylcarnitine* has too many nan (58/26). This will be excluded
# beta-cryptoxanthin has too many nan (26/26). This will be excluded
# biotin has too many nan (104/26). This will be excluded
# bradykinin has too many nan (128/26). This will be excluded
# bradykinin, des-arg(9) has too many nan (130/26). This will be excluded
# branched-chain, straight-chain, or cyclopropyl 10:1 fatty acid (2)* has too many nan (27/26). This will be excluded
# campesterol has too many nan (94/26). This will be excluded
# carboxyibuprofen has too many nan (107/26). This will be excluded
# catechol glucuronide has too many nan (60/26). This will be excluded
# celecoxib has too many nan (126/26). This will be excluded
# cetirizine has too many nan (126/26). This will be excluded
# chenodeoxycholic acid sulfate (1) has too many nan (66/26). This will be excluded
# chiro-inositol has too many nan (49/26). This will be excluded
# chlorthalidone has too many nan (129/26). This will be excluded
# cholic acid glucuronide has too many nan (63/26). This will be excluded
# citalopram N-oxide* has too many nan (118/26). This will be excluded
# citalopram propionate* has too many nan (118/26). This will be excluded
# cotinine has too many nan (101/26). This will be excluded
# cytidine has too many nan (49/26). This will be excluded
# delta-CEHC glucuronide has too many nan (35/26). This will be excluded
# delta-tocopherol has too many nan (59/26). This will be excluded
# desmethylcitalopram* has too many nan (118/26). This will be excluded
# desmethylnaproxen has too many nan (114/26). This will be excluded
# desmethylnaproxen sulfate has too many nan (111/26). This will be excluded
# dextromethorphan has too many nan (126/26). This will be excluded
# dihydrocaffeate sulfate (2) has too many nan (31/26). This will be excluded
# dihydroferulate has too many nan (37/26). This will be excluded
# diltiazem has too many nan (127/26). This will be excluded
# diphenhydramine has too many nan (116/26). This will be excluded
# docosahexaenoylcarnitine (C22:6)* has too many nan (47/26). This will be excluded
# doxycycline has too many nan (130/26). This will be excluded
# duloxetine has too many nan (130/26). This will be excluded
# escitalopram has too many nan (118/26). This will be excluded
# ethyl maltol sulfate has too many nan (112/26). This will be excluded
# ethylparaben sulfate has too many nan (38/26). This will be excluded
# eugenol sulfate has too many nan (28/26). This will be excluded
# ferulic acid 4-sulfate has too many nan (28/26). This will be excluded
# fexofenadine has too many nan (127/26). This will be excluded
# ADSGEGDFXAEGGGVR* has too many nan (124/26). This will be excluded
# DSGEGDFXAEGGGVR* has too many nan (119/26). This will be excluded
# ADpSGEGDFXAEGGGVR* has too many nan (127/26). This will be excluded
# fluoxetine has too many nan (128/26). This will be excluded
# furosemide has too many nan (127/26). This will be excluded
# gabapentin has too many nan (126/26). This will be excluded
# genistein sulfate* has too many nan (113/26). This will be excluded
# glucuronide of C10H18O2 (1)* has too many nan (76/26). This will be excluded
# glucuronide of C10H18O2 (7)* has too many nan (26/26). This will be excluded
# glucuronide of C10H18O2 (8)* has too many nan (75/26). This will be excluded
# glucuronide of C12H22O4 (1)* has too many nan (41/26). This will be excluded
# glucuronide of piperine metabolite C17H21NO3 (5)* has too many nan (28/26). This will be excluded
# glycerol 3-phosphate has too many nan (41/26). This will be excluded
# glycocholate glucuronide (1) has too many nan (66/26). This will be excluded
# glycodeoxycholate has too many nan (32/26). This will be excluded
# glycolithocholate has too many nan (31/26). This will be excluded
# glycoursodeoxycholic acid sulfate (1) has too many nan (39/26). This will be excluded
# heme has too many nan (50/26). This will be excluded
# heneicosapentaenoate (21:5n3) has too many nan (86/26). This will be excluded
# hexanoylglycine (C6) has too many nan (26/26). This will be excluded
# hydrochlorothiazide has too many nan (98/26). This will be excluded
# hydroxybupropion has too many nan (126/26). This will be excluded
# hydroxycotinine has too many nan (100/26). This will be excluded
# I-urobilinogen has too many nan (62/26). This will be excluded
# ibuprofen has too many nan (123/26). This will be excluded
# ibuprofen acyl glucuronide has too many nan (113/26). This will be excluded
# indolebutyrate has too many nan (32/26). This will be excluded
# isoursodeoxycholate sulfate (1) has too many nan (47/26). This will be excluded
# L-urobilin has too many nan (69/26). This will be excluded
# leucylglycine has too many nan (39/26). This will be excluded
# leucylphenylalanine/isoleucylphenylalanine has too many nan (26/26). This will be excluded
# lidocaine has too many nan (126/26). This will be excluded
# linezolid has too many nan (127/26). This will be excluded
# lisinopril has too many nan (108/26). This will be excluded
# lithocholic acid sulfate (2) has too many nan (52/26). This will be excluded
# maltol sulfate has too many nan (51/26). This will be excluded
# metformin has too many nan (120/26). This will be excluded
# methotrexate has too many nan (123/26). This will be excluded
# methyl indole-3-acetate has too many nan (42/26). This will be excluded
# metoprolol has too many nan (97/26). This will be excluded
# metoprolol acid metabolite* has too many nan (75/26). This will be excluded
# N,O-didesmethylvenlafaxine glucuronide has too many nan (127/26). This will be excluded
# N-acetyl sulfapyridine has too many nan (113/26). This will be excluded
# N-acetyl-3-methylhistidine* has too many nan (42/26). This will be excluded
# N-acetyl-cadaverine has too many nan (46/26). This will be excluded
# N-acetylalliin has too many nan (30/26). This will be excluded
# N-acetylkynurenine (2) has too many nan (27/26). This will be excluded
# N-desmethyl tramadol has too many nan (121/26). This will be excluded
# N-ethylglycinexylidide has too many nan (127/26). This will be excluded
# N-linoleoylglycine has too many nan (47/26). This will be excluded
# N-linoleoyltaurine* has too many nan (42/26). This will be excluded
# N-palmitoylserine has too many nan (54/26). This will be excluded
# N-palmitoyltaurine has too many nan (64/26). This will be excluded
# N1,N12-diacetylspermine has too many nan (48/26). This will be excluded
# naproxen has too many nan (104/26). This will be excluded
# nervonoylcarnitine (C24:1)* has too many nan (81/26). This will be excluded
# NAD+ has too many nan (33/26). This will be excluded
# norcotinine has too many nan (113/26). This will be excluded
# norfluoxetine has too many nan (128/26). This will be excluded
# O-desmethyltramadol has too many nan (122/26). This will be excluded
# O-desmethyltramadol glucuronide has too many nan (122/26). This will be excluded
# O-desmethylvenlafaxine has too many nan (127/26). This will be excluded
# olmesartan has too many nan (129/26). This will be excluded
# omeprazole has too many nan (98/26). This will be excluded
# oxypurinol has too many nan (126/26). This will be excluded
# pantoprazole has too many nan (124/26). This will be excluded
# paroxetine has too many nan (129/26). This will be excluded
# pregnanediol-3-glucuronide has too many nan (26/26). This will be excluded
# promethazine has too many nan (128/26). This will be excluded
# propyl 4-hydroxybenzoate sulfate has too many nan (40/26). This will be excluded
# quinine has too many nan (119/26). This will be excluded
# ranitidine has too many nan (128/26). This will be excluded
# ranitidine N-oxide* has too many nan (128/26). This will be excluded
# resveratrol disulfate (1)* has too many nan (111/26). This will be excluded
# resveratrol disulfate (2)* has too many nan (122/26). This will be excluded
# resveratrol sulfate (1)* has too many nan (127/26). This will be excluded
# resveratrol sulfate (2)* has too many nan (106/26). This will be excluded
# S-allylcysteine has too many nan (36/26). This will be excluded
# saccharin has too many nan (50/26). This will be excluded
# salicyluric glucuronide* has too many nan (38/26). This will be excluded
# sedoheptulose has too many nan (33/26). This will be excluded
# sertraline has too many nan (121/26). This will be excluded
# solanidine has too many nan (73/26). This will be excluded
# spermine has too many nan (27/26). This will be excluded
# sulfate of piperine metabolite C18H21NO3 (3)* has too many nan (29/26). This will be excluded
# tartarate has too many nan (70/26). This will be excluded
# tauro-beta-muricholate has too many nan (50/26). This will be excluded
# tauroursodeoxycholate has too many nan (46/26). This will be excluded
# THC carboxylic acid has too many nan (125/26). This will be excluded
# THC carboxylic acid glucuronide has too many nan (124/26). This will be excluded
# theanine has too many nan (120/26). This will be excluded
# tramadol has too many nan (124/26). This will be excluded
# trazadone has too many nan (120/26). This will be excluded
# triamterene has too many nan (126/26). This will be excluded
# umbelliferone sulfate has too many nan (49/26). This will be excluded
# valsartan has too many nan (129/26). This will be excluded
# valylglycine has too many nan (46/26). This will be excluded
# vanillate glucuronide has too many nan (77/26). This will be excluded
# vanillic alcohol sulfate has too many nan (52/26). This will be excluded
# venlafaxine has too many nan (127/26). This will be excluded
# warfarin has too many nan (123/26). This will be excluded
# xanthosine has too many nan (91/26). This will be excluded
# zolpidem has too many nan (127/26). This will be excluded
# 210
