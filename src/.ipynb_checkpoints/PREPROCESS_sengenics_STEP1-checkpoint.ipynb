# %%
import pandas as pd
import numpy as np

# %%
input_file = '/Users/m221138/RA_sero_multiomics/raw_data/RA_sengenics/sengenics_raw_data.csv'

#transpose_data
data_df = pd.read_csv(input_file, sep=",", index_col=0)
data_df = data_df.T

# %%
data_df = np.log2(data_df)
data_df
# Out:
#           21228000113  21228000114  21228000115  21228000116  21228000117  \
# A1BG        10.724727    10.156399     9.708222     9.105254     9.328114
# AAK1        11.602235    11.382759    10.612177     9.865347    10.512987
# AARS        10.834669    10.484068     9.818050     9.074810     9.416270
# ABCF1       11.088457    10.595957    10.177420     8.941781     9.299780
# ABCF3       11.501340    11.168359    10.071127     9.426789     9.846274
# ...               ...          ...          ...          ...          ...
# zzz_igg2    11.595491    11.805038    11.742520    11.741046    12.523194
# zzz_igg3    10.543757    10.695663    10.663336    10.625709    12.107299
# zzz_igg4     9.573647     9.853699     9.681238     9.733863    11.750079
# zzz_igg5     8.739781     8.854868     8.740624     8.763212    11.677389
# zzz_igg6     7.726218     7.753217     7.577429     7.731319    11.594558
#
#           21228000118  21228000119  21228000120  21228000121  21228000122  \
# ...

# %%
data_df.to_csv('/Users/m221138/RA_sero_multiomics/preprocessed_data/autoantibody/sengenics_log2raw.tsv', sep="\t")
